# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/dpv lab/sleeptime_prediction_dataset.csv")
df.head()
# Out:
#    WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0         1.12         0.52       3.29       7.89          216.08
# 1         2.85         0.49       4.22       5.03          206.18
# 2         2.20         1.81       4.04       9.23           28.73
# 3         1.80         0.50       1.62       7.68          276.77
# 4         0.47         0.54       1.60       4.94          170.54
#
#    RelaxationTime  SleepTime
# 0            0.75       3.45
# 1            0.67       4.88
# 2            0.35       3.61
# 3            1.21       4.94
# 4            0.95       5.50

# %%
df.isnull().sum()
# Out:
# WorkoutTime       0
# ReadingTime       0
# PhoneTime         0
# WorkHours         0
# CaffeineIntake    0
# RelaxationTime    0
# SleepTime         0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
df.describe()
# Out:
#        WorkoutTime  ReadingTime    PhoneTime    WorkHours  CaffeineIntake  \
# count  2000.000000  2000.000000  2000.000000  2000.000000     2000.000000
# mean      1.495915     0.992785     2.985195     6.926945      147.493780
# std       0.876639     0.577303     1.151776     1.723843       84.651139
# min       0.010000     0.000000     1.000000     4.000000        0.020000
# 25%       0.710000     0.500000     1.990000     5.440000       75.980000
# 50%       1.520000     0.990000     2.965000     6.910000      146.010000
# 75%       2.250000     1.500000     3.960000     8.422500      218.902500
# max       3.000000     2.000000     5.000000    10.000000      299.850000
#
#        RelaxationTime    SleepTime
# count     2000.000000  2000.000000
# mean         1.010955     4.884375
# std          0.582619     2.028892
# min          0.000000     0.150000
# 25%          0.510000     3.840000
# 50%          1.010000     4.600000
# 75%          1.530000     5.470000
# ...

# %%
x=df.drop("SleepTime",axis=1)
y=df['SleepTime']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
linear_model=LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linear_model.predict(x_test)
ans={"Actual Value":y_test,"Predicted Value":y_pred}
print(ans)
# Out:
# {'Actual Value': 682     3.00
# 701     4.36
# 1250    4.76
# 1675    4.79
# 47      4.42
#         ...
# 1149    5.93
# 61      5.09
# 1978    3.90
# 346     4.49
# 86      4.82
# Name: SleepTime, Length: 400, dtype: float64, 'Predicted Value': array([2.27850853, 4.65980146, 5.00632676, 5.09128346, 4.5024713 ,
#        4.95473218, 3.52624998, 5.69046932, 7.33356262, 4.85690134,
#        3.4886841 , 4.86278057, 5.12010943, 6.20790033, 5.8249233 ,
#        4.95136646, 4.7165919 , 6.17151465, 5.64988297, 3.77984292,
#        3.96548362, 4.84115944, 5.5293188 , 5.29285192, 5.47925886,
#        3.96687637, 7.02370421, 3.90237399, 6.05520191, 4.59362897,
#        5.08546744, 5.48758681, 4.05852749, 5.41431703, 4.85888883,
#        3.79122859, 6.32027777, 5.44823848, 6.11563497, 6.33052311,
#        5.03503324, 4.5084399 , 4.9944918 , 6.12229407, 5.2530455 ,
#        4.11867033, 4.489049  , 3.66358132, 4.25246838, 5.11833554,
# ...

# %%
ans1=mean_squared_error(y_test,y_pred)
print(ans1)
# Out:
# 3.300919430489705

# %%
ans2=mean_absolute_error(y_test,y_pred)
print(ans2)
# Out:
# 0.5705987523555494

# %%
ans3=r2_score(y_test,y_pred)
print(ans3)
# Out:
# 0.23067446061857044

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred=rf_regressor.predict(x_test)
ans={"Actual Value":y_test,"Predicted Value":y_pred}
print(ans)
# Out:
# {'Actual Value': 682     3.00
# 701     4.36
# 1250    4.76
# 1675    4.79
# 47      4.42
#         ...
# 1149    5.93
# 61      5.09
# 1978    3.90
# 346     4.49
# 86      4.82
# Name: SleepTime, Length: 400, dtype: float64, 'Predicted Value': array([3.2371, 4.4893, 4.7037, 4.8263, 5.8516, 5.1074, 3.5331, 5.676 ,
#        8.0256, 4.4221, 3.3352, 4.7426, 4.4999, 6.5415, 5.6082, 5.1792,
#        4.0494, 6.1071, 5.4993, 3.8098, 3.9964, 4.9352, 5.2886, 5.0605,
#        5.4756, 3.5601, 6.8202, 4.0191, 7.6606, 4.6357, 4.9677, 5.5419,
#        4.2882, 5.0008, 4.6873, 3.7743, 6.5509, 5.2256, 6.0549, 5.9147,
#        5.859 , 4.1147, 5.3881, 6.5922, 5.0511, 3.9656, 3.9941, 3.4346,
#        3.9732, 4.9737, 4.2715, 7.2268, 5.1314, 3.8472, 6.5449, 3.6118,
#        5.0564, 6.0699, 4.3322, 3.5631, 6.8704, 3.5779, 4.0896, 4.3957,
#        5.5419, 7.059 , 4.8473, 4.8836, 5.9594, 4.3924, 4.0303, 3.7841,
#        4.3424, 3.4355, 4.3052, 5.6339, 4.3063, 5.8069, 5.5054, 3.4356,
# ...

# %%
ans1=mean_absolute_error(y_test,y_pred)
print(ans1)
# Out:
# 0.7318489999999999

# %%
ans2=r2_score(y_test,y_pred)
print(ans2 )
# Out:
# 0.11615777819243711

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [ 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# Initialize GridSearchCV
grid_search = GridSearchCV(
    estimator=RandomForestRegressor(random_state=42),
    param_grid=param_grid,
    cv=5,  # 5-fold cross-validation
    scoring='r2',  # Optimize for R² score
    n_jobs=-1
)

# Perform the grid search
grid_search.fit(x_train, y_train)

# Get the best parameters and re-train the model
best_params = grid_search.best_params_
optimized_rf = grid_search.best_estimator_

# Make predictions with the optimized model
y_pred_optimized = optimized_rf.predict(x_test)

# Evaluate the optimized model
mae_optimized = mean_absolute_error(y_test, y_pred_optimized)
r2_optimized = r2_score(y_test, y_pred_optimized)

best_params, mae_optimized, r2_optimized
# Out:
# ({'max_depth': 20,
#   'min_samples_leaf': 2,
#   'min_samples_split': 5,
#   'n_estimators': 100},
#  0.6809191003850316,
#  0.14748860769694228)

# %%
import joblib
joblib.dump(optimized_rf, 'sleep.pkl')
# Out:
# ['sleep.pkl']

# %%
import numpy as np
model=joblib.load('sleep.pkl')
input_data = (1,3,5,216,1,1)
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)
# Out:
# [3.1289706]
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
